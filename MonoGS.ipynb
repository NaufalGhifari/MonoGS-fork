# %%
# %cd drive/MyDrive/Github
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/Github'
# /content/drive/MyDrive/Github

# %%
# from google.colab import userdata
# token = userdata.get("GITHUB_TOKEN")
# !git clone --recursive https://{token}@github.com/NaufalGhifari/MonoGS-fork.git
# Out:
# Cloning into 'MonoGS-fork'...
# remote: Enumerating objects: 227, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 227 (delta 103), reused 80 (delta 77), pack-reused 58 (from 1)
# Receiving objects: 100% (227/227), 25.24 MiB | 18.98 MiB/s, done.
# Resolving deltas: 100% (104/104), done.
# Submodule 'submodules/diff-gaussian-rasterization' (https://github.com/rmurai0610/diff-gaussian-rasterization-w-pose.git) registered for path 'submodules/diff-gaussian-rasterization'
# Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'submodules/simple-knn'
# Cloning into '/content/drive/MyDrive/Github/MonoGS-fork/submodules/diff-gaussian-rasterization'...
# remote: Enumerating objects: 240, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (25/25), done.
# ...

# %%
# %cd /content/drive/MyDrive/Github/MonoGS-fork/
# !git pull
# Out:
# /content/drive/MyDrive/Github/MonoGS-fork
# Already up to date.

# %%
import os
os.environ["CUDA_HOME"] = "/usr/local/cuda"

# %%
# %cd drive/MyDrive/Github/MonoGS-fork
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/Github/MonoGS-fork'
# /content/drive/MyDrive/Github/MonoGS-fork

# %%
# !pip install -r pip_requirements_colab.txt

# %%
# Then install the rasterizer as before
# %cd /content/drive/MyDrive/Github/MonoGS-fork/submodules/diff-gaussian-rasterization
# !pip install .
# Out:
# /content/drive/MyDrive/Github/MonoGS-fork/submodules/diff-gaussian-rasterization
# Processing /content/drive/MyDrive/Github/MonoGS-fork/submodules/diff-gaussian-rasterization
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for diff_gaussian_rasterization: filename=diff_gaussian_rasterization-0.0.0-cp312-cp312-linux_x86_64.whl size=3809070 sha256=994a2d4c58ca51f196682551437a648ce3608b43bb8b76fe668eaabab43b274d
#   Stored in directory: /root/.cache/pip/wheels/71/39/61/f2f11def54880953f34ccce88041400e1db7656ba86b15758d
# Successfully built diff_gaussian_rasterization
# ...
#   Attempting uninstall: diff_gaussian_rasterization
#     Found existing installation: diff_gaussian_rasterization 0.0.0
#     Uninstalling diff_gaussian_rasterization-0.0.0:
#       Successfully uninstalled diff_gaussian_rasterization-0.0.0
# ...

# %%
# %cd /content/drive/MyDrive/Github/MonoGS-fork/submodules/simple-knn
FILE_PATH="/content/drive/MyDrive/Github/MonoGS-fork/submodules/simple-knn/simple_knn.cu"
# !sed -i '1i #include <float.h>' "$FILE_PATH"
# !pip install -v .
# Out:
# /content/drive/MyDrive/Github/MonoGS-fork/submodules/simple-knn
# Using pip 24.1.2 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)
# Processing /content/drive/MyDrive/Github/MonoGS-fork/submodules/simple-knn
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-9ihqbskj/simple_knn.egg-info
#   writing /tmp/pip-pip-egg-info-9ihqbskj/simple_knn.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-9ihqbskj/simple_knn.egg-info/dependency_links.txt
#   writing top-level names to /tmp/pip-pip-egg-info-9ihqbskj/simple_knn.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-9ihqbskj/simple_knn.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-9ihqbskj/simple_knn.egg-info/SOURCES.txt'
#   writing manifest file '/tmp/pip-pip-egg-info-9ihqbskj/simple_knn.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# ...
#   Running command python setup.py bdist_wheel
# ...

# %%
# !bash scripts/download_tum_1.sh

# %%
# %cd /content/drive/MyDrive/Github/MonoGS-fork
# !python slam.py --config ./configs/mono/tum/fr1_desk.yaml --eval
# Out:
# /content/drive/MyDrive/Github/MonoGS-fork
# MonoGS: Running MonoGS in Evaluation Mode
# MonoGS: Following config will be overriden
# MonoGS:         save_results=True
# MonoGS:         use_gui=False
# MonoGS:         eval_rendering=True
# MonoGS:         use_wandb=False
# MonoGS: saving results in
# results/tum_rgbd_dataset_freiburg1_desk/2026-05-06-10-21-32
# MonoGS: Resetting the system
# MonoGS: Initialized map
# MonoGS: Resetting the opacity of non-visible Gaussians
# MonoGS: Keyframes lacks sufficient overlap to initialize the map, resetting.
# MonoGS: Resetting the system
# MonoGS: Initialized map
# MonoGS: Resetting the opacity of non-visible Gaussians
# MonoGS: Performing initial BA for initialization
# MonoGS: Initialized SLAM
# MonoGS: Evaluating ATE at frame:  74
# Eval: RMSE ATE [m] 0.00979319951374076
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Github/MonoGS-fork/slam.py", line 252, in <module>
#     slam = SLAM(config, save_dir=save_dir)
# ...

# %%
# %cd /content/drive/MyDrive/Github/MonoGS-fork
# Force the 'Agg' backend via an environment variable or a python inline command
# !time python slam.py --config configs/mono/tum/fr1_desk.yaml --eval
# Out:
# /content/drive/MyDrive/Github/MonoGS-fork
# MonoGS: Running MonoGS in Evaluation Mode
# MonoGS: Following config will be overriden
# MonoGS:         save_results=True
# MonoGS:         use_gui=False
# MonoGS:         eval_rendering=True
# MonoGS:         use_wandb=False
# MonoGS: saving results in
# results/tum_rgbd_dataset_freiburg1_desk/2026-05-06-11-12-42
# MonoGS: Resetting the system
# MonoGS: Initialized map
# MonoGS: Resetting the opacity of non-visible Gaussians
# MonoGS: Keyframes lacks sufficient overlap to initialize the map, resetting.
# MonoGS: Resetting the system
# MonoGS: Initialized map
# MonoGS: Resetting the opacity of non-visible Gaussians
# MonoGS: Performing initial BA for initialization
# MonoGS: Initialized SLAM
# MonoGS: Evaluating ATE at frame:  80
# Eval: RMSE ATE  0.008614430257705164
# MonoGS: Evaluating ATE at frame:  131
# Eval: RMSE ATE  0.009642324677498119
# MonoGS: Evaluating ATE at frame:  172
# Eval: RMSE ATE  0.01318113677878732
# ...
